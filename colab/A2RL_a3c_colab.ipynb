# %% [markdown]
# # A2RL A3C Training (Colab Version)
#
# This notebook acts as a launcher for the A2RL A3C training agent on Google Colab.

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# 2. Setup Paths
import os
import sys

# CHANGE THIS TO YOUR PROJECT PATH
PROJECT_PATH = '/content/drive/MyDrive/A2RL/A2RL-Test'
COLAB_SCRIPT_PATH = os.path.join(PROJECT_PATH, 'colab')

# Verify path
if not os.path.exists(PROJECT_PATH):
    print(f"Error: Path {PROJECT_PATH} does not exist. Please check your Drive structure.")
else:
    print(f"Project path found: {PROJECT_PATH}")
    
# Add project root to system path so imports work
if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)
    print("Added project path to sys.path")

# %%
# 3. Install Dependencies
# %cd {COLAB_SCRIPT_PATH}
# !pip install -r requirements.txt

# %%
# 4. Run Training
# We run the script directly. 
# Note: We are running the colab-specific script which handles imports and config.

# %cd {COLAB_SCRIPT_PATH}
# !python A2RL_a3c_colab.py
