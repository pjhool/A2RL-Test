# %%
# !pip install google-auth-oauthlib google-auth-httplib2 google-api-python-client
# Out:
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.12/dist-packages (0.2.0)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (2.185.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib) (2.38.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-oauthlib) (2.0.0)
# Requirement already satisfied: httplib2>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-auth-httplib2) (0.31.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client) (2.26.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.71.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (1.26.1)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.5)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.15.0->google-auth-oauthlib) (4.9.1)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2>=0.19.0->google-auth-httplib2) (3.2.5)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-auth-oauthlib) (0.6.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2025.11.12)

# %%
# %cd /kaggle/working

# %%
# %pwd

# %%
! git clone https://github.com/pjhool/A2RL-Test.git
# Out:
# Cloning into 'A2RL-Test'...
# remote: Enumerating objects: 1026, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 1026 (delta 7), reused 14 (delta 7), pack-reused 1012 (from 2)
# Receiving objects: 100% (1026/1026), 13.18 MiB | 47.67 MiB/s, done.
# Resolving deltas: 100% (648/648), done.

# %%
# %cd /kaggle/working/A2RL-Test
# Out:
# /kaggle/working/A2RL-Test

# %%
from huggingface_hub import hf_hub_download, login

# Kaggle Notebook에서
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login

# Secret 가져오기
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("HF_TOKEN")

# Hugging Face 로그인
login(token=hf_token)
# 인증 없이 시도
from huggingface_hub import snapshot_download

# 레포 전체 다운로드
local_dir = snapshot_download(
    repo_id="pjhool/a2rl",
    local_dir="/kaggle/working/A2RL-Test",
    local_dir_use_symlinks=False  # Windows 호환성
)
#print(f"Downloaded: {file_path}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:979: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# model-spp-max.index:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# a2rl_model/model-spp-avg.data-00000-of-0(…):   0%|          | 0.00/119M [00:00<?, ?B/s]
# model-spp-avg.index:   0%|          | 0.00/1.22k [00:00<?, ?B/s]
# a2rl_model/model-wo-spp.data-00000-of-00(…):   0%|          | 0.00/92.4M [00:00<?, ?B/s]
# a2rl_model/model-spp-max.meta:   0%|          | 0.00/9.58M [00:00<?, ?B/s]
# a2rl_model/model-spp-max.data-00000-of-0(…):   0%|          | 0.00/179M [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.96k [00:00<?, ?B/s]
# a2rl_model/model-spp-avg.meta:   0%|          | 0.00/9.65M [00:00<?, ?B/s]
# model-wo-spp.index:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# a2rl_model/model-wo-spp.meta:   0%|          | 0.00/9.64M [00:00<?, ?B/s]
# vfn_rl.pkl:   0%|          | 0.00/146M [00:00<?, ?B/s]

# %%
import os
os.chdir("/kaggle/working/A2RL-Test/colab")

# %%
#!python check_gpu.py

# %%
# !pwd
# !ls -al
# Out:
# /kaggle/working/A2RL-Test/colab
# total 256
# drwxr-xr-x 2 root root   4096 Jan 11 04:54 .
# drwxr-xr-x 9 root root   4096 Jan 11 04:54 ..
# -rw-r--r-- 1 root root   3170 Jan 11 04:54 A2RL_a3c_colab.ipynb
# -rw-r--r-- 1 root root 141967 Jan 11 04:54 A2RL_a3c_colab.py
# -rw-r--r-- 1 root root   1542 Jan 11 04:54 A2RL_a3c.py
# -rw-r--r-- 1 root root   5176 Jan 11 04:54 actions.py
# -rw-r--r-- 1 root root   1030 Jan 11 04:54 check_gpu.py
# -rw-r--r-- 1 root root   2691 Jan 11 04:54 config_colab-local.py
# -rw-r--r-- 1 root root   6978 Jan 11 04:54 config_colab.py
# -rw-r--r-- 1 root root  22143 Jan 11 04:54 kaggle_gdrive_uploader.py
# -rw-r--r-- 1 root root   2388 Jan 11 04:54 logger_config.py
# -rw-r--r-- 1 root root   7936 Jan 11 04:54 network.py
# -rw-r--r-- 1 root root   7329 Jan 11 04:54 network_vfn.py
# -rw-r--r-- 1 root root   5679 Jan 11 04:54 optuna_tune.py
# -rw-r--r-- 1 root root    120 Jan 11 04:54 requirements.txt
# -rw-r--r-- 1 root root   8939 Jan 11 04:54 summary_download_helper.py
# -rw-r--r-- 1 root root   5536 Jan 11 04:54 tensorboard_kaggle.py

# %%
# %cd /kaggle/working/A2RL-Test/colab
# Out:
# /kaggle/working/A2RL-Test/colab

# %%
import os

# 빠른 테스트 설정
os.environ['A2RL_EPOCH_SIZE'] = '200'      # 5 에포크만
os.environ['A2RL_BATCH_SIZE'] = '32'     # 작은 배치
os.environ['A2RL_THREADS'] = '4'         # 2 스레드
os.environ['A2RL_T_MAX'] = '50'          # 짧은 에피소드
os.environ['A2RL_CONSOLE_LOG_LEVEL'] = 'WARNING'
# 약 8시간 정도만 학습하고 Kaggle 시간 제한 전에 안전하게 종료하고 싶을 때
os.environ['A2RL_MAX_TRAIN_HOURS'] = '8.0' 
# 총 500 에피소드만 학습하고 종료하고 싶을 때
os.environ['A2RL_MAX_EPISODES'] = '700000'
os.environ['A2RL_STOP_REWARD'] = '-1'
os.environ['A2RL_BETA'] = '0.005'
os.environ['A2RL_MIN_STEPS'] = '2'
os.environ['A2RL_CURRICULUM'] = '0'

os.environ['A2RL_USE_LSTM'] = '0' 
os.environ['A2RL_ACTOR_LR'] = '5.0e-6'
os.environ['A2RL_CRITIC_LR'] = '5.0e-6' 
os.environ['A2RL_ENABLE_GRAD_CLIP'] = '1' 
os.environ['A2RL_USE_LAYER_NORM'] = '1' 
os.environ['A2RL_VALIDATION_FREQ'] = '5'  
os.environ['A2RL_MINI_BATCH_SIZE'] = '32'  
#os.environ['A2RL_LOAD_WEIGHTS'] = '/kaggle/working/save_model/20260111/'    
os.environ['A2RL_LOAD_WEIGHTS'] = ''
# %cd /kaggle/working/A2RL-Test/colab 
# !python A2RL_a3c_colab.py  --download_weights  
#!python optuna_tune.py
# !python A2RL_a3c_colab.py  # -- first run 
#!python A2RL_a3c_colab.py --load_weights /kaggle/working/A2RL-Test/colab/latest_model_cache/20260110/
# Out:
# /kaggle/working/A2RL-Test
# Config: Detected Kaggle Environment
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768139448.359528     153 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768139448.365404     153 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768139448.380423     153 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768139448.380454     153 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768139448.380459     153 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768139448.380466     153 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 13:50:59 - WARNING - ✓ Using GDrive token from Kaggle Secrets (GDRIVE_TOKEN)
# 13:50:59 - WARNING - ✓ Google Drive authentication successful
#  flattened_dim size  = 12544
# I0000 00:00:1768139468.831149     153 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1768139468.834943     153 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768139468.868175     153 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# 13:51:09 - WARNING - USE_FILTERED_DATA is True but filtered path is empty or missing. Falling back to TRAIN_PATH.
# 13:51:09 - WARNING - ============================================================
# 13:51:09 - WARNING - ENVIRONMENT CONFIGURATION STATUS:
# 13:51:09 - WARNING -   A2RL_STOP_REWARD: -1 (Current: -1.00)
# 13:51:09 - WARNING -   A2RL_MIN_STEPS:   2 (Current: 2)
# 13:51:09 - WARNING -   A2RL_BETA:        0.005 (Current: 0.0050)
# 13:51:09 - WARNING -   A2RL_BATCH_SIZE:  32 (Current: 32)
# 13:51:09 - WARNING -   A2RL_THREADS:     4 (Current: 4)
# 13:51:09 - WARNING -   A2RL_T_MAX:       50 (Current: 50)
# 13:51:09 - WARNING -   CONSOLE_LOG:      WARNING
# 13:51:09 - WARNING - ============================================================
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/backend.py:452: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/training_v1.py:2354: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# I0000 00:00:1768139469.856981     153 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1768139469.857247     153 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# 13:51:10 - WARNING - Loading initial weights from: ./latest_model_cache/20260111/A2RL_a3c_periodic_20260111132819
# 13:51:10 - WARNING - Loading model from: ./latest_model_cache/20260111/A2RL_a3c_periodic_20260111132819
# 13:51:10 - WARNING - Loaded metadata: {'fold': 0, 'epoch': 0, 'episode': 577112, 'status': 'periodic'}
# 13:51:10 - WARNING - Continuous episode count from loaded weights: 577112
# 13:51:10 - WARNING - ============================================================
# 13:51:10 - WARNING - DATASET PREPARATION
# 13:51:10 - WARNING - ============================================================
# 13:51:14 - WARNING - Pre-validating 3766 images in /kaggle/input/a2rl-ava/train (load_images=True)...
# ^C
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-2:
# Config: Detected Kaggle Environment
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768139483.552803     197 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768139483.558690     197 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768139483.574215     197 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768139483.574243     197 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768139483.574248     197 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768139483.574253     197 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
#  flattened_dim size  = 12544
# I0000 00:00:1768139488.311207     197 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1768139488.311987     197 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1768139488.345561     197 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# ^C
# Traceback (most recent call last):
#   File "/kaggle/working/A2RL-Test/colab/A2RL_a3c_colab.py", line 3000, in <module>
#     global_agent = A3CAgent(action_size=config.ACTION_SIZE)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/A2RL-Test/colab/A2RL_a3c_colab.py", line 814, in __init__
#     self.actor, self.critic = self.build_model()
#                               ^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/A2RL-Test/colab/A2RL_a3c_colab.py", line 1276, in build_model
#     fc1_ln = LayerNormalization()(fc1_dense)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/base_layer_v1.py", line 844, in __call__
#     outputs = call_fn(cast_inputs, *args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tf_keras/src/layers/normalization/layer_normalization.py", line 324, in call
#     scale = tf.ones([pre_dim], dtype=self.dtype)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/util/dispatch.py", line 1260, in op_dispatch_handler
#     return dispatch_target(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/array_ops.py", line 2970, in ones
#     output = fill(shape, constant(one, dtype=dtype), name=name, layout=layout)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py", line 150, in error_handler
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/util/dispatch.py", line 1260, in op_dispatch_handler
#     return dispatch_target(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/array_ops.py", line 246, in fill
#     result = d_api.call_with_layout(
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/dtensor/python/api.py", line 37, in call_with_layout
#     @tf_export("experimental.dtensor.call_with_layout", v1=[])
#
# KeyboardInterrupt

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 568 bytes | 94.00 KiB/s, done.
# From https://github.com/pjhool/A2RL-Test
#    87b24dd..014ff8c  main       -> origin/main
# Updating 87b24dd..014ff8c
# Fast-forward
#  colab/A2RL_a3c_colab.py | 8 +++++++-
#  1 file changed, 7 insertions(+), 1 deletion(-)

# %%
# !pip install optuna

# %%
#%reload_ext tensorboard
#%tensorboard --logdir /kaggle/working/summary/A2RL_a3c/20251227/event_094410/events.out.tfevents.1766828650.1bf3ab5

# %%
# !tar cvf /kaggle/working/summary-20251230.tar /kaggle/working/summary

# %%
# !tar cvf /kaggle/working/logs-20251230.tar /kaggle/working/logs/20251230

# %%
# 학습 완료 후 별도 셀에서 실행
import sys
sys.path.append('/kaggle/working/A2RL-Test/colab')
from summary_download_helper import download_summary
# 다운로드 링크 표시
download_summary()

# %%
#import sys
#sys.path.append('/kaggle/working/A2RL-Test/colab')
#from tensorboard_kaggle import start_tensorboard

#start_tensorboard()

# %%
# !killall -9 tensorboard
# !ps auxww | grep -i tensor

# %%
# !ps auxww | grep -i colab
